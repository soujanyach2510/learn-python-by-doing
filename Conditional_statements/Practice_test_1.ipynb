# %% [markdown]
# 1. Name of the keyword which helps in writing code involves condition?
#
# Ans: If ,else and elif

# %%
# Write the simple syntax of if statment


# ans
age=int(input("Enter the age:"))
if age>40:
    print("middle age")
# Out:
# Enter the age:41
# middle age

# %% [markdown]
# # is there any limit of statments that can appear under if block
#
# Ans There’s no limit to how many statements you can put inside an if block —
# but it’s best to keep it clean, readable, and maintainable.

# %%
# write a program to check weather a person is eligble for driving licence or not(accept age from user)

age=int(input("Enter the age:"))

if age>21:
    print("Eligible for driving ")
else:
    print("Not eligible")
# Out:
# Enter the age:22
# Eligible for driving

# %%
# write a program weather number entered by user is an odd or even

num=int(input("Enter the number: "))

if(num%2==0):
        print("even_number")
else:
        print("odd_number")
# Out:
# Enter the number: 15
# odd_number

# %%
# write a program to check weather a number is divisible by 8 or not

# ans
num=int(input("Enter the number: "))

if(num%8==0):
        print("divisible by 8")
else:
        print("not divisible by 8")
# Out:
# Enter the number: 64
# divisible by 8

# %%
# write a program to display "Datavizon" if a number entered by user is a multiple of 6, other wise print "Good morning"

# ans

num=int(input("Enter the number: "))

if(num%6==0):
        print("Datavizon")
else:
        print("Good morning")
# Out:
# Enter the number: 24
# Datavizon

# %%
# write a program  to calcualate the electricity bill(accpet number from user) according to below conditions


#Unit                            price

#First 100 units                no charge
#Next 100 units                 Rs 5 per unit
#After 200 units                Rs 10 per unit

#(for example if input unit is 350 then total bill amount is 2000)


# Ans:

units=int(input("Enter the number of units: "))
if(units<=100):
  print("No charge")
elif(units>100 and units<=200):
  print(units*5)
else:
  print(units*10)
# Out:
# Enter the number of units: 101
# 505

# %%
# Write a program to display the last digit of a number

#(hint: any number % 10 will return the last digit)

# ans

number=int(input("Enter the number: "))
last_digit=number%10
print(last_digit)
# Out:
# Enter the number: 25
# 5

# %%
# write a program to cehck weather the last digit of number(entered by user) is divisible  by 4 or not

# ans
number=int(input("Enter the number: "))
last_digit=number%10
if(last_digit%4==0):
  print("divisible by 4")
else:
  print("not divisible by 4")
# Out:
# Enter the number: 42
# not divisible by 4
