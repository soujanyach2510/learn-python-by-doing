# %%
# Ask user to give name and marks of 10 different students. Store them in dictionary.

#ans:

students={}
for i in range(10):
    name=input("Enter name: ")
    marks=int(input("Enter marks: "))
    students[name]=marks
print(students)
# Out:
# Enter name: deepu
# Enter marks: 76
# Enter name: mani
# Enter marks: 65
# Enter name: souji
# Enter marks: 98
# Enter name: neha
# Enter marks: 45
# Enter name: jushi
# Enter marks: 88
# Enter name: hima
# Enter marks: 75
# Enter name: mouni
# Enter marks: 65
# Enter name: kittu
# Enter marks: 89
# Enter name: gopu
# Enter marks: 99
# Enter name: latha
# Enter marks: 67
# {'deepu': 76, 'mani': 65, 'souji': 98, 'neha': 45, 'jushi': 88, 'hima': 75, 'mouni': 65, 'kittu': 89, 'gopu': 99, 'latha': 67}

# %%
# Sort the dictionary created in previous example according to marks.

#ans
sorted_students_dict=dict(sorted(students.items(),key=lambda x:x[1]))
print(sorted_students_dict)
# Out:
# {'neha': 45, 'mani': 65, 'mouni': 65, 'latha': 67, 'hima': 75, 'deepu': 76, 'jushi': 88, 'kittu': 89, 'souji': 98, 'gopu': 99}

# %%
# Use dictionary to store antonyms of words. E.g.- 'Right':'Left', 'Up':'Down', etc.
# Display all words and then ask user to enter a word and display antonym of it.

#ans
antonyms={}
for i in range(3):
  word=input("Enter word ")
  anto=input("Enter antonym ")
  antonyms[word]=anto
print(antonyms)
word=input("Enter a word:")
print(antonyms[word])
# Out:
# Enter word up
# Enter antonym down
# Enter word right
# Enter antonym left
# Enter word correct
# Enter antonym wrong
# {'up': 'down', 'right': 'left', 'correct': 'wrong'}
# Enter a word:right
# left

# %%
# Count the number of occurrence of each letter in word "MISSISSIPPI".
# Store count of every letter with the letter in a dictionary.

#ans
word="MISSISSIPPI"
count={}
for i in word:
  if i in count:
    count[i]+=1
  else:
    count[i]=1
print(count)
# Out:
# {'M': 1, 'I': 4, 'S': 4, 'P': 2}

# %%
# From the previous question, sort according to the number of letters.

#ans
sorted_count=dict(sorted(count.items(),key=lambda x:x[1]))
print(sorted_count)
# Out:
# {'M': 1, 'P': 2, 'I': 4, 'S': 4}

# %%
# Take a list containg only strings. Now, take a string input from user and rearrange the elements of the list according to the number of occurence of the string taken from user in the elements of the list.
# E.g.-LIST : ["no bun","bug bun bug bun bug bug","bunny bug","buggy bug bug buggy"]
#STRING TAKEN : "bug"
# OUTPUT LIST:["bug bun bug bun bug bug","buggy bug bug buggy","bunny bug","no bun"]

#ans
lst=["no bun","bug bun bug bun bug bug","bunny bug","buggy bug bug buggy"]
search_str=input("Enter a string:")
filtered_lst=[x for x in lst if search_str in x]
sorted_lst=sorted(filtered_lst,key=lambda x:x.count(search_str),reverse=True)
print(sorted_lst)
# Out:
# Enter a string:bug
# ['bug bun bug bun bug bug', 'buggy bug bug buggy', 'bunny bug']
